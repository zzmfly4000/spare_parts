# %% [markdown]
# 进入Spare_parts项目管理目录

# %%
# !cd C:\Users\zmzhao\PycharmProjects\spare_parts

# %% [markdown]
# 激活虚拟环境

# %%
# !venv\Scripts\activate
# Out:
# ϵͳ�Ҳ���ָ����·����

# %% [markdown]
# 生成依赖清单

# %%
# !pip freeze > requirements.txt

# %% [markdown]
# 启动Spare_parts程序

# %%
# !python run.py
# Out:
# python: can't open file 'C:\\Users\\zmzhao\\PycharmProjects\\spare_parts\\docs\\run.py': [Errno 2] No such file or directory
